# %% [markdown]
# python 打开二进制文件

# %%
import os
binfile="5x2.tif"
tiff=open(binfile,"rb")
size=os.path.getsize(binfile)
for i in range(size):
    data=tiff.read(1)
    print(data)
tiff.close()
# Out:
# b'I'
# b'I'
# b'*'
# b'\x00'
# b'"'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x80'
# b'?'
# b'\xe0'
# b'O'
# b'\xf0'
# b'\x0c'
# b'\x14'
# b'\x01'
# b'\x03'
# b'\x00'
# b'A'
# b'@'
# b'0'
# b'x'
# b'\x10'
# b'\x02'
# b'\x1d'
# b'\x0c'
# b'\x86'
# b'\xc2'
# b'\xa2'
# b'\x10'
# b'\x98'
# b'4'
# b'\x04'
# b'\x00'
# b'\x15'
# b'\x00'
# b'\xfe'
# b'\x00'
# b'\x04'
# b'\x00'
# b'\x01'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x01'
# b'\x04'
# b'\x00'
# b'\x01'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x05'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x01'
# b'\x01'
# b'\x04'
# b'\x00'
# b'\x01'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x02'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x02'
# b'\x01'
# b'\x03'
# b'\x00'
# b'\x04'
# b'\x00'
# b'\x00'
# b'\x00'
# b'$'
# b'\x01'
# b'\x00'
# b'\x00'
# b'\x03'
# b'\x01'
# b'\x03'
# b'\x00'
# b'\x01'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x05'
# b'\x00'
# b'\x00'
# b'\x00'
# b'\x06'
# b'\x01'
# b'\x03'
# b'\x00'
# b'\x01'
# b'\x00'
# b'\x00'
# ...
